# %% [markdown]
# ## Input and Type Conversion

# %%
userName = input("Enter user name:")

print(f"Yoo, it's {userName}!")
# Out:
# Enter user name: Joob
# Yoo, it's Joob!

# %%
age = int(input("yo how old are you:"))

print(f"Yo... so you're telling me {userName} is {age}? Crazy.")
# Out:
# yo how old are you: 9
# Yo... so you're telling me Joob is 9? Crazy.

# %%
priceText = "9.99"
priceNum = float(priceText)
print(priceNum * 2)
# Out:
# 19.98

# %%
score = 67
scoreText = str(score)
print(f"yo score is lowkey {scoreText}.")

if score == 67:
    print("... six seven.")
# Out:
# yo score is lowkey 67.
# ... six seven.

# %%
prite = float(input("how much do it cost money moeny:"))
tax = 8
print(f"you cowest the uhm... {round(float(prite + (prite * (tax / 100))), 2)} buckaroos. Dosh. it's pretty true.")
# Out:
# how much do it cost money moeny: 67.41
# you cowest the uhm... 72.8 buckaroos. Dosh. it's pretty true.

# %%
#age calularto
#author: joob
#purpose gt da year and then it uhm get the ag efom the yar

birthYear = int(input("whn we you born year: "))
year = 2026

print(f"aha... you are certainly... {2026 - birthYear} yaer old... muehehe")
